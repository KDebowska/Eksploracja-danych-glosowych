# %%
# Jeśli jeszcze nie zainstalowany:
pip install pydub

# %%
import wave
from pydub import AudioSegment as auds
import pandas as pd
import numpy as np
import os, fnmatch
from matplotlib import pyplot as plt
import scipy.io.wavfile as wf
from scipy.integrate import simps

# %%
# Z kilkoma plikami jest problem, nie wszystkie słowa się eksportują, co powoduje błędy później w liczeniu parametrów
# Ten skrypt działa dla plików:
# 0 289516_25_K_01_2.txt 289516_25_K_01_2.wav
# 1 289516_25_K_10_3.txt 289516_25_K_10_3.wav
# 2 289516_25_K_16_4.txt 289516_25_K_16_4.wav
# 3 289516_25_K_22_1.txt 289516_25_K_22_1.wav
# 4 289540_23_K_13_2.txt 289540_23_K_13_2.wav
# 5 289540_23_K_18_3.txt 289540_23_K_18_3.wav
# 6 289540_23_K_22_4.txt 289540_23_K_22_4.wav
# 7 289540_23_K_9_1.txt 289540_23_K_9_1.wav
# 8 289550_23_K_18_2.txt 289550_23_K_18_2.wav
# 9 289550_23_K_23_3.txt 289550_23_K_23_3.wav
# 10 289550_23_K_23_4.txt 289550_23_K_23_4.wav
# 11 289550_23_K_9_1.txt 289550_23_K_9_1.wav
# 12 289556_24_K_11_1.txt 289556_24_K_11_1.wav
# 13 289556_24_K_15_2.txt 289556_24_K_15_2.wav
# 14 289556_24_K_19_3.txt 289556_24_K_19_3.wav
# 15 289556_24_K_23_4.txt 289556_24_K_23_4.wav
# 16 404907_23_K_11_1.txt 404907_23_K_11_1.wav
# 17 404907_23_K_14_2.txt 404907_23_K_14_2.wav

# Przynajmniej u mnie, jeśli w folderze ze ścieżki mam też inne pliki poza tymi wymienionymi,
# to w pewnym momencie liczenie się zacina, może to jakiś problem z mojej strony

# %%
path = 'C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania'

# Wyciaganie nazw plikow ze sciezki
list_of_files = os.listdir(path)
pattern = "*.txt"
list_of_names = []
for entry in list_of_files:
    if fnmatch.fnmatch(entry, pattern):
            list_of_names.append(entry[:-4])

# Utworzenie list plikow wav i txt
files_wav_list = []
files_txt_list = []
for filename in list_of_names:
    files_wav_list.append(filename + '.wav')
    files_txt_list.append(filename + '.txt')
    
print('Obecne pliki:')

for i in range(len(list_of_names)):
    print(i, files_txt_list[i], files_wav_list[i])
print('liczba plikow: ', len(list_of_names))
# Out:
# Obecne pliki:
# 0 289516_25_K_01_2.txt 289516_25_K_01_2.wav
# 1 289516_25_K_10_3.txt 289516_25_K_10_3.wav
# 2 289516_25_K_16_4.txt 289516_25_K_16_4.wav
# 3 289516_25_K_22_1.txt 289516_25_K_22_1.wav
# 4 289540_23_K_13_2.txt 289540_23_K_13_2.wav
# 5 289540_23_K_18_3.txt 289540_23_K_18_3.wav
# 6 289540_23_K_22_4.txt 289540_23_K_22_4.wav
# 7 289540_23_K_9_1.txt 289540_23_K_9_1.wav
# 8 289550_23_K_18_2.txt 289550_23_K_18_2.wav
# 9 289550_23_K_23_3.txt 289550_23_K_23_3.wav
# 10 289550_23_K_23_4.txt 289550_23_K_23_4.wav
# 11 289550_23_K_9_1.txt 289550_23_K_9_1.wav
# 12 289556_24_K_11_1.txt 289556_24_K_11_1.wav
# 13 289556_24_K_15_2.txt 289556_24_K_15_2.wav
# 14 289556_24_K_19_3.txt 289556_24_K_19_3.wav
# 15 289556_24_K_23_4.txt 289556_24_K_23_4.wav
# 16 289592_24_K_12_1.txt 289592_24_K_12_1.wav
# 17 289592_24_K_15_2.txt 289592_24_K_15_2.wav
# 18 289592_24_K_19_3.txt 289592_24_K_19_3.wav
# 19 289592_24_K_7_4.txt 289592_24_K_7_4.wav
# 20 404907_23_K_11_1.txt 404907_23_K_11_1.wav
# 21 404907_23_K_14_2.txt 404907_23_K_14_2.wav
# 22 404907_23_K_16_3.txt 404907_23_K_16_3.wav
# 23 404907_23_K_20_4.txt 404907_23_K_20_4.wav
# liczba plikow:  24

# %%
# TO CHYBA JEDNAK JEST NIEPOTRZEBNE, ALE SZKODA MI USUWAĆ, TO ZAKOMENTUJĘ :D


# # Liczenie parametrów zapisywanych do plików osób (w każdym pliku 98 wartości, kolejne słowa jednej osoby)

# # Parametr: pole powierzchni pod krzywą z wartości bezwzględnej sygnału (area)
# # Parametr: gęstość przejść przez 0 (zeros)

# folder_name_area = path + '/' + 'Area_osoby' + '/' # tworzenie folderu na wyniki danego parametru
# folder_name_zeros = path + '/' + 'Zeros_osoby' + '/'
# for i in range(len(list_of_names)): # iteracja po 18 plikach
#     print('i = ', i)
#     filename = list_of_names[i]
#     file_wav = files_wav_list[i]
#     file_txt = files_txt_list[i]
#     labels = []
#     # Wczytywanie plikow z etykietami
#     textfile = pd.read_csv(path + '/' + file_txt, sep = '\t', header = None)
#     osoba = []
#     print("Z nagrania:", filename)
#     # Wczytywanie etykiet i odpowiadających im słów, zapisywanie do listy
#     for j in range(98): # iteracja po kolejnych słowach z jednego pliku
#         labels.append(str(textfile[2][j]))
#         if labels[j] == 'nan':
#             labels[j] = 'NA'
#         labels[j] = labels[j].upper() 
#         word_path = path + '/' + labels[j]
#         # Sprawdź, czy istnieje plik o danej nazwie
#         if os.path.isfile(word_path + '/' + filename + '_' + '{0}.wav'.format(labels[j])) == True:
#             new_filename = filename + '_' + labels[j] + '.wav'
# #             print(j)
#             word = wave.open(word_path + '/' + new_filename, 'rb')
#             # Jeśli ilość ramek nieparzysta, to nie zadziała, więc wtedy wczytujemy wszystkie ramki oprócz ostatniej
#             if word.getnframes() % 2 != 0:
#                 word_frames = word.readframes(word.getnframes()-1)
#             else:
#                 word_frames = word.readframes(word.getnframes())
#             word_frames = np.frombuffer(word_frames, dtype=int)
#             osoba.append(word_frames)
        
#     # Operacje na liście wszystkich słów z danego nagrania
#     area_person = []
#     zeros_person = []
#     for k in range(len(osoba)): # iteracja po kolejnych słowach
# #         if k < 10:
# #             print('k =',  k)
#         # np. dodaj linijkę "folder_name_nazwa_parametru = path + '/' + 'Nazwa_parametru_osoby' + '/'"
#         if os.path.isdir(folder_name_area) == False:
#             os.mkdir(folder_name_area)
#         if os.path.isdir(folder_name_zeros) == False:
#             os.mkdir(folder_name_zeros)
# #         print('Pierwsze 5 plików:')
#         # for j in range(len(list_of_names)):
#         zeros_cnt = 0
#         area_person.append(simps(np.abs(osoba[k])))
#         for m in range(1, len(osoba[k])):
#             if (osoba[k][m] <= 0 and osoba[k][m-1] > 0) or (osoba[k][m] >= 0 and osoba[k][m-1] < 0):
#                 zeros_cnt += 1
#     # >>> skopiuj linijkę powyżej i zmień na <nazwa_parametru_person>.append(<wyliczanie parametru>(osoba[i])) <<<
#     # Zapis wartości do pliku tekstowego
#         zeros_person.append(zeros_cnt)
# #         print('k = ', k, 'Dodano gęstość przejść przez zero')
#     txt_person_filename_area = folder_name_area + 'area_' + list_of_names[i] + '.txt'
#     txt_person_filename_zeros = folder_name_zeros + 'zeros_' + list_of_names[i] + '.txt'
#     if os.path.isfile(txt_person_filename_area) == False:
#         np.savetxt(txt_person_filename_area, area_person)
#         print('Zapisano jako:', txt_person_filename_area)
#     else:
#         print('Plik', list_of_names[i], 'z AREA już istnieje') 
#     if os.path.isfile(txt_person_filename_zeros) == False:
#         np.savetxt(txt_person_filename_zeros, zeros_person)
#         print('Zapisano jako:', txt_person_filename_zeros)
#     elif os.path.isfile(txt_person_filename_zeros) == True:
#         print('Plik', list_of_names[i], 'z ZEROS już istnieje')

# %%
# Liczenie parametrów zapisywanych do plików słów (w każdym pliku 24 wartości, kolejne osoby wypowiadające to samo słowo)

area_folder_name = path + '/' + 'Area_słowa' + '/' # tworzenie folderu na wyniki danego parametru
zeros_folder_name = path + '/' + 'Zeros_słowa' + '/'

for j in range(98):
    print(j)
    labels = []
    if j > 0:
        for a in range(0, j):
            labels.append('')
    area_word = []
    zeros_word = []
    zeros_cnt = 0
    slowo = []
    for i in range(len(list_of_names)):
        filename = list_of_names[i]
        file_wav = files_wav_list[i]
        file_txt = files_txt_list[i]
        textfile = pd.read_csv(path + '/' + file_txt, sep = '\t', header = None)
        labels.append(str(textfile[2][j]))
        if labels[j] == 'nan':
            labels[j] = 'NA'
        labels[j] = labels[j].upper()
        if i == 0:
            print(labels[j])
        person_path = path + '/' + labels[j]
        # Sprawdź, czy istnieje plik o danej nazwie
        if os.path.isfile(person_path + '/' + filename + '_' + '{0}.wav'.format(labels[j])) == True:
            new_filename = filename + '_' + labels[j] + '.wav'
            person = wave.open(person_path + '/' + new_filename, 'rb')
            # Jeśli ilość ramek nieparzysta, to nie zadziała, więc wtedy wczytujemy wszystkie ramki oprócz ostatniej
            if person.getnframes() % 2 != 0:
                person_frames = person.readframes(person.getnframes()-1)
            else:
                person_frames = person.readframes(person.getnframes())
            person_frames = np.frombuffer(person_frames, dtype=int)
            slowo.append(person_frames)
            if os.path.isdir(area_folder_name) == False:
                os.mkdir(area_folder_name)
            if os.path.isdir(zeros_folder_name) == False:
                os.mkdir(zeros_folder_name)
            area_word.append(simps(np.abs(slowo[i])))
            for m in range(1, len(slowo[i])):
                if (slowo[i][m] <= 0 and slowo[i][m-1] > 0) or (slowo[i][m] >= 0 and slowo[i][m-1] < 0):
                    zeros_cnt += 1
            zeros_word.append(zeros_cnt)
    area_txt_person_filename = area_folder_name + 'area_' + labels[j] + '.txt'
    zeros_txt_person_filename = zeros_folder_name + 'zeros_' + labels[j] + '.txt'
    if os.path.isfile(area_txt_person_filename) == False:
        np.savetxt(area_txt_person_filename, area_word)
        print('Zapisano jako:', area_txt_person_filename)
    else:
        print('Plik', labels[j], 'z AREA już istnieje') 
    if os.path.isfile(zeros_txt_person_filename) == False:
        np.savetxt(zeros_txt_person_filename, zeros_word)
        print('Zapisano jako:', zeros_txt_person_filename)
    elif os.path.isfile(zeros_txt_person_filename) == True:
        print('Plik', labels[j], 'z ZEROS już istnieje')
# Out:
# 0
# OTWORZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_OTWORZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_OTWORZ.txt
# 1
# WLACZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_WLACZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_WLACZ.txt
# 2
# SWIATLO
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_SWIATLO.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_SWIATLO.txt
# 3
# TELEWIZOR
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_TELEWIZOR.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_TELEWIZOR.txt
# 4
# ZAMKNIJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZAMKNIJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZAMKNIJ.txt
# 5
# KUCHNI
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_KUCHNI.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_KUCHNI.txt
# 6
# NA
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_NA.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_NA.txt
# 7
# DRZWI
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_DRZWI.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_DRZWI.txt
# 8
# LAZIENCE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_LAZIENCE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_LAZIENCE.txt
# 9
# WYLACZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_WYLACZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_WYLACZ.txt
# 10
# W
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_W.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_W.txt
# 11
# OKNO
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_OKNO.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_OKNO.txt
# 12
# PIEKARNIK
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PIEKARNIK.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PIEKARNIK.txt
# 13
# ROLETY
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ROLETY.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ROLETY.txt
# 14
# TEMPERATURE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_TEMPERATURE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_TEMPERATURE.txt
# 15
# RADIO
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_RADIO.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_RADIO.txt
# 16
# DO
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_DO.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_DO.txt
# 17
# POKOJU
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_POKOJU.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_POKOJU.txt
# 18
# USTAW
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_USTAW.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_USTAW.txt
# 19
# SYPIALNI
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_SYPIALNI.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_SYPIALNI.txt
# 20
# PRALKE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PRALKE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PRALKE.txt
# 21
# GARAZU
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_GARAZU.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_GARAZU.txt
# 22
# ALARM
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ALARM.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ALARM.txt
# 23
# BRAME
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_BRAME.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_BRAME.txt
# 24
# CZAJNIK
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_CZAJNIK.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_CZAJNIK.txt
# 25
# ZGAS
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZGAS.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZGAS.txt
# 26
# ZAPAL
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZAPAL.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZAPAL.txt
# 27
# SALONIE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_SALONIE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_SALONIE.txt
# 28
# WODE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_WODE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_WODE.txt
# 29
# KOMPUTER
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_KOMPUTER.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_KOMPUTER.txt
# 30
# PODNIES
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PODNIES.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PODNIES.txt
# 31
# ZWIEKSZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZWIEKSZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZWIEKSZ.txt
# 32
# OGRZEWANIE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_OGRZEWANIE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_OGRZEWANIE.txt
# 33
# PRZEDPOKOJU
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PRZEDPOKOJU.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PRZEDPOKOJU.txt
# 34
# KLIMATYZACJE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_KLIMATYZACJE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_KLIMATYZACJE.txt
# 35
# ZMIEN
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZMIEN.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZMIEN.txt
# 36
# OKNA
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_OKNA.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_OKNA.txt
# 37
# MUZYKE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_MUZYKE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_MUZYKE.txt
# 38
# ZMYWARKE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZMYWARKE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZMYWARKE.txt
# 39
# PIWNICY
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PIWNICY.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PIWNICY.txt
# 40
# ZMNIEJSZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZMNIEJSZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZMNIEJSZ.txt
# 41
# ZASLON
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZASLON.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZASLON.txt
# 42
# KANAL
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_KANAL.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_KANAL.txt
# 43
# OPUSC
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_OPUSC.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_OPUSC.txt
# 44
# ZASUN
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZASUN.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZASUN.txt
# 45
# LODOWKE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_LODOWKE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_LODOWKE.txt
# 46
# ZAGOTUJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZAGOTUJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZAGOTUJ.txt
# 47
# PODLEJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PODLEJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PODLEJ.txt
# 48
# BUDZIK
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_BUDZIK.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_BUDZIK.txt
# 49
# ZALUZJE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZALUZJE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZALUZJE.txt
# 50
# PODGLOSNIJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PODGLOSNIJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PODGLOSNIJ.txt
# 51
# KAWE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_KAWE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_KAWE.txt
# 52
# O
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_O.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_O.txt
# 53
# ODSLON
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ODSLON.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ODSLON.txt
# 54
# EKSPRES
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_EKSPRES.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_EKSPRES.txt
# 55
# JEDEN
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_JEDEN.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_JEDEN.txt
# 56
# KORYTARZU
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_KORYTARZU.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_KORYTARZU.txt
# 57
# GARAZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_GARAZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_GARAZ.txt
# 58
# STRYCHU
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_STRYCHU.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_STRYCHU.txt
# 59
# PRZYCIEMNIJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PRZYCIEMNIJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PRZYCIEMNIJ.txt
# 60
# UCHYL
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_UCHYL.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_UCHYL.txt
# 61
# ROZJASNIJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ROZJASNIJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ROZJASNIJ.txt
# 62
# ZABLOKUJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZABLOKUJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZABLOKUJ.txt
# 63
# STOPNI
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_STOPNI.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_STOPNI.txt
# 64
# ZROB
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZROB.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZROB.txt
# 65
# DOMU
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_DOMU.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_DOMU.txt
# 66
# HERBATE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_HERBATE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_HERBATE.txt
# 67
# PRZYGOTUJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PRZYGOTUJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PRZYGOTUJ.txt
# 68
# SCHODACH
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_SCHODACH.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_SCHODACH.txt
# 69
# PODAJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PODAJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PODAJ.txt
# 70
# SUSZARKE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_SUSZARKE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_SUSZARKE.txt
# 71
# WEJSCIOWE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_WEJSCIOWE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_WEJSCIOWE.txt
# 72
# LAZIENKI
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_LAZIENKI.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_LAZIENKI.txt
# 73
# WODY
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_WODY.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_WODY.txt
# 74
# ZEWNATRZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZEWNATRZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZEWNATRZ.txt
# 75
# DWA
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_DWA.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_DWA.txt
# 76
# ZADZWON
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZADZWON.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZADZWON.txt
# 77
# SPUSC
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_SPUSC.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_SPUSC.txt
# 78
# CZTERY
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_CZTERY.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_CZTERY.txt
# 79
# GLOSNIEJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_GLOSNIEJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_GLOSNIEJ.txt
# 80
# PROGRAM
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PROGRAM.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PROGRAM.txt
# 81
# SCISZ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_SCISZ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_SCISZ.txt
# 82
# STOPIEN
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_STOPIEN.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_STOPIEN.txt
# 83
# Z
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_Z.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_Z.txt
# 84
# GARDEROBIE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_GARDEROBIE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_GARDEROBIE.txt
# 85
# ZAKREC
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ZAKREC.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ZAKREC.txt
# 86
# LAMPKE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_LAMPKE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_LAMPKE.txt
# 87
# TARASIE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_TARASIE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_TARASIE.txt
# 88
# LOZKO
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_LOZKO.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_LOZKO.txt
# 89
# GABINECIE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_GABINECIE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_GABINECIE.txt
# 90
# KWIATKI
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_KWIATKI.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_KWIATKI.txt
# 91
# OSWIETLENIE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_OSWIETLENIE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_OSWIETLENIE.txt
# 92
# TRZY
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_TRZY.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_TRZY.txt
# 93
# STACJE
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_STACJE.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_STACJE.txt
# 94
# ODBLOKUJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_ODBLOKUJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_ODBLOKUJ.txt
# 95
# PALNIK
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_PALNIK.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_PALNIK.txt
# 96
# CISZEJ
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_CISZEJ.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_CISZEJ.txt
# 97
# OKAP
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Area_słowa/area_OKAP.txt
# Zapisano jako: C:/Dysk D/STUDIA/Eksploracja danych biomedycznych/Nagrania/Zeros_słowa/zeros_OKAP.txt
